# %% [markdown]
# # Google Search Ranking & Discoverability Capstone
#
# ## Project Setup
#
# This notebook is the starting point for the capstone project.
#
# The goal of this project is to build a reproducible search intelligence analysis or machine learning workflow using the provided FlyRank dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys

# %% [markdown]
# ## Environment Check
#
# Before working with the dataset, I verify that the notebook is running in the intended Python environment.

# %%
print(sys.version)
print(sys.executable)
# Out:
# 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]
# c:\Users\anasm\Anaconda\python.exe

# %%
print(f"numpy: {np.__version__}")
print(f"pandas: {pd.__version__}")
print(f"matplotlib: {plt.matplotlib.__version__}")
print(f"seaborn: {sns.__version__}")
# Out:
# numpy: 1.26.4
# pandas: 2.2.2
# matplotlib: 3.9.2
# seaborn: 0.13.2
